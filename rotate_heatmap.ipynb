# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from matplotlib.transforms import Affine2D
import mpl_toolkits.axisartist.floating_axes as floating_axes

# %%
from sklearn.datasets import load_iris
import pandas as pd

# Load the Iris dataset
iris = load_iris()

# Convert to a Pandas DataFrame
iris_df = pd.DataFrame(
    data=iris.data,
    columns=iris.feature_names
)
iris_df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
corr_ = iris_df.sample(25,random_state=42).T.corr()
corr_ = corr_ ** 2
upper_tri = corr_.where(np.triu(np.ones(corr_.shape), k=1).astype(bool))
#upper_tri = corr_.where(np.tril(np.ones(corr_.shape), k=-1).astype(bool))
upper_tri
# Out:
#      73        18        118       78        76        31        64   \
# 73   NaN  0.539719  0.905548  0.997462  0.989715  0.539468  0.949036
# 18   NaN       NaN  0.254858  0.571747  0.561258  0.996641  0.743386
# 118  NaN       NaN       NaN  0.893361  0.902280  0.261936  0.761339
# 78   NaN       NaN       NaN       NaN  0.996383  0.574710  0.965474
# 76   NaN       NaN       NaN       NaN       NaN  0.569427  0.963188
# 31   NaN       NaN       NaN       NaN       NaN       NaN  0.748830
# 64   NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 141  NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 68   NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 82   NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 110  NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 12   NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 36   NaN       NaN       NaN       NaN       NaN       NaN       NaN
# ...

# %%
# Out:
#     0         1         2         3         4         5         6         7  \
# 0 NaN  0.658541  0.766116  0.845921  0.613604  0.088605  0.487628  0.077649
# 1 NaN       NaN  0.110998  0.808235  0.947688  0.072316  0.955115  0.522577
# 2 NaN       NaN       NaN  0.050226  0.072902  0.402873  0.295290  0.232384
# 3 NaN       NaN       NaN       NaN  0.476437  0.226029  0.640476  0.978981
# 4 NaN       NaN       NaN       NaN       NaN  0.585865  0.624784  0.071776
# 5 NaN       NaN       NaN       NaN       NaN       NaN  0.775346  0.271409
# 6 NaN       NaN       NaN       NaN       NaN       NaN       NaN  0.046852
# 7 NaN       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 8 NaN       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 9 NaN       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
#           8         9
# 0  0.407543  0.407106
# 1  0.299566  0.076862
# 2  0.281004  0.803483
# 3  0.603493  0.357814
# ...

# %%
# Out:
# Index([ 73,  18, 118,  78,  76,  31,  64, 141,  68,  82, 110,  12,  36,   9,
#         19,  56, 104,  69,  55, 132,  29, 127,  26, 128, 131],
#       dtype='int64')

# %%
from matplotlib.lines import Line2D

# %%
w, h = 13, 6
# Create a base canvas
fig, ax = plt.subplots(figsize=(w, h), dpi=600)

fig.text(0.5, 0.5, 'My Fixed Text', ha='center', va='center', color='black', zorder=10,backgroundcolor='white')

# Horizontal line at y=0.5 in figure coordinates
h_line = Line2D([0, 1], [0.5, 0.5], color='black', transform=fig.transFigure)
fig.add_artist(h_line)

# Vertical line at x=0.5 in figure coordinates
v_line = Line2D([0.5, 0.5], [0, 1], color='black', transform=fig.transFigure)
fig.add_artist(v_line)


ax1 = fig.add_axes([0.1, 0.5, 0.8, 0.4])  # [left, bottom, width, height]
ax2 = fig.add_axes([0.1, 0.1, 0.8, 0.4])


ax1.set_facecolor('red')
ax2.set_facecolor('lightblue')



ax1.set_axis_off()
ax2.set_axis_off()

plt.show()

# %%
corr_ = iris_df.sample(100,random_state=42).T.corr()
corr_ = corr_ ** 2
upper_tri = corr_#.where(np.triu(np.ones(corr_.shape), k=1).astype(bool))

w, h = 13, 6
# Create a base canvas
fig, ax = plt.subplots(figsize=(w, h), dpi=600)
# Center the image on the canvas
x_center, y_center = 0, 2.5  # Center in normalized figure coordinates
width, height = 0.5, 0.5       # Size of the image relative to the canvas

# Create an axes in the center for imshow
image_ax = fig.add_axes([x_center - width / 2, y_center - height / 2, width, height])

# Apply rotation
rotation = 45  # Degrees
transform = Affine2D().rotate_deg(rotation) + image_ax.transData

# Display the image with rotation
hmap = image_ax.imshow(upper_tri, cmap="Greens",
                interpolation='none',
                transform=transform,
                #extent=(-1, 1, -1, 1),
                extent=(-3.5, 3.5, -3.5, 3.5),
                vmin=0,vmax=1,
                clip_on=False,
                origin='upper')

# fig.colorbar(hmap, ax=ax,
#              anchor=(0.5, 0.1),
#              shrink=0.15,
#              orientation='horizontal')

plt.text(-3.5, -0.5, '(-3.5, -0.5)', fontsize=20, rotation=90, ha='center', va='center')
plt.text(3.5, -0.5, '(3.5, -0.5)', fontsize=20, rotation=90, ha='center', va='center')

plt.hlines(-0.0, -5.5, 5.5, color='black', linewidth=1)
plt.vlines(0.5, -5.5, 5.5, color='black', linewidth=1)

plt.ylim(0, 5)
ax.set_axis_off()
image_ax.set_axis_off()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[138], line 33
#      20 hmap = image_ax.imshow(upper_tri, cmap="Greens",
#      21                 interpolation='none',
#      22                 transform=transform,
#    (...)
#      26                 clip_on=False,
#      27                 origin='upper')
#      29 # fig.colorbar(hmap, ax=ax,
#      30 #              anchor=(0.5, 0.1),
#      31 #              shrink=0.15,
#      32 #              orientation='horizontal')
# ---> 33 a
#      34 plt.text(-3.5, -0.5, '(-3.5, -0.5)', fontsize=20, rotation=90, ha='center', va='center')
#      35 plt.text(3.5, -0.5, '(3.5, -0.5)', fontsize=20, rotation=90, ha='center', va='center')
#
# NameError: name 'a' is not defined

# %%
w, h = 13, 6
# Create a base canvas
fig, ax = plt.subplots(figsize=(w, h), dpi=600)

fig.text(0.5, 0.5, 'My Fixed Text', ha='center', va='center', color='black', zorder=10,backgroundcolor='white')

# Horizontal line at y=0.5 in figure coordinates
h_line = Line2D([0, 1], [0.5, 0.5], color='black', transform=fig.transFigure)
fig.add_artist(h_line)

# Vertical line at x=0.5 in figure coordinates
v_line = Line2D([0.5, 0.5], [0, 1], color='black', transform=fig.transFigure)
fig.add_artist(v_line)


ax1 = fig.add_axes([0.1, 0.5, 0.8, 0.4])  # [left, bottom, width, height]
ax2 = fig.add_axes([0.1, 0.1, 0.8, 0.4])


ax1.set_facecolor('red')
ax2.set_facecolor('lightblue')



ax1.set_axis_off()
ax2.set_axis_off()

plt.show()

# %%
dir(hmap)
# Out:
# ['_A',
#  '_PROPERTIES_EXCLUDED_FROM_SET',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_agg_filter',
#  '_alpha',
#  '_animated',
#  '_axes',
#  '_callbacks',
#  '_check_unsampled_image',
#  '_clipon',
#  '_clippath',
#  '_cm_set',
#  '_different_canvas',
#  '_extent',
#  '_filternorm',
#  '_filterrad',
#  '_fully_clipped_to_axes',
#  '_get_scalar_alpha',
#  '_gid',
#  '_id_norm',
#  '_imcache',
#  '_in_layout',
#  '_internal_update',
#  '_interpolation',
#  '_interpolation_stage',
#  '_label',
#  '_make_image',
#  '_mouseover',
#  '_norm',
#  '_normalize_image_array',
#  '_path_effects',
# ...

# %%
hmap.get_

# %%
fig = plt.figure(figsize=(h, w))

ax1 = fig.add_axes([0.05, 0.05, 0.9, 0.9], aspect=1)
plt.imshow(upper_tri, cmap='Blues', interpolation='nearest',vmin=0,vmax=1)


ax1.set_xticklabels([])
ax1.set_yticklabels([])

ax1.xaxis.set_ticks([])
ax1.yaxis.set_ticks([])
ax1.spines["top"].set_visible(False)
ax1.spines["left"].set_visible(False)
ax1.spines["right"].set_visible(False)
ax1.spines["bottom"].set_visible(False)


rotation = 45
transform = Affine2D().rotate_deg(rotation-90)
helper = floating_axes.GridHelperCurveLinear(transform, (0, 1, 0, 1))

ax2 = floating_axes.FloatingSubplot(fig, 111, grid_helper=helper, zorder=0,)

ax2.patch.set_facecolor('green')  # Set the face color
ax2.patch.set_alpha(0.3)  
fig.add_subplot(ax2) 

# Remove all ticks, tick labels, and axis spines
ax2.axis["left"].major_ticklabels.set_visible(False)
ax2.axis["bottom"].major_ticklabels.set_visible(False)
ax2.axis["bottom"].major_ticks.set_visible(False)  # Remove bottom ticks
ax2.axis["left"].major_ticks.set_visible(False)    # Remove left ticks


ax2.axis["left"].set_visible(False)
ax2.axis["right"].set_visible(False)
ax2.axis["top"].set_visible(False)
ax2.axis["bottom"].set_visible(False)
ax1.set_visible(False)

ax_rotated_aux = ax2.get_aux_axes(transform)
ax_rotated_aux.imshow(upper_tri, cmap='Blues', interpolation='nearest',vmin=0,vmax=1)

# %%
h, w = 12,12
fig = plt.figure(figsize=(h, w))
ax1 = fig.add_axes([0.05, 0.05, 0.9, 0.9], aspect=1)

#sns.heatmap(upper_tri, cmap='Greens', cbar=False,ax=ax1)
ax1.set_xticklabels([])
ax1.set_yticklabels([])
ax1.xaxis.set_ticks([])
ax1.yaxis.set_ticks([])
ax1.spines["top"].set_visible(False)
ax1.spines["right"].set_visible(False)

rotation = 90

xmin, xmax = -18, 18                              
ymin, ymax = 0, xmax - xmin                       
transform = Affine2D().rotate_deg(rotation-90)
helper = floating_axes.GridHelperCurveLinear(transform, (xmin, xmax, ymin, ymax))
ax2 = floating_axes.FloatingSubplot(fig, 111, grid_helper=helper, zorder=100)


ax2.patch.set_facecolor('green')  # Set the face color
ax2.patch.set_alpha(0.3)  

fig.add_subplot(ax2) 

# Remove all ticks, tick labels, and axis spines
ax2.axis["left"].major_ticklabels.set_visible(False)
ax2.axis["bottom"].major_ticklabels.set_visible(False)
ax2.axis["bottom"].major_ticks.set_visible(False)  # Remove bottom ticks
ax2.axis["left"].major_ticks.set_visible(False)    # Remove left ticks


ax2.axis["left"].set_visible(False)
ax2.axis["right"].set_visible(False)
ax2.axis["top"].set_visible(False)
ax2.axis["bottom"].set_visible(False)

# Optionally remove ticks entirely from the axis
ax2.set_xticks([])
ax2.set_yticks([])

# Ensure the axis patch remains visible if required
ax2.patch.set_visible(True)

ax2_aux = ax2.get_aux_axes(transform)
sns.heatmap(upper_tri, cmap='Blues', cbar=False,ax=ax2_aux)

#ax1.set_visible(False)
ax2.figure

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from matplotlib.transforms import Affine2D
import mpl_toolkits.axisartist.floating_axes as floating_axes

# Create figure and sample data
h, w = 12, 12
upper_tri = np.triu(np.random.rand(10, 10))
fig = plt.figure(figsize=(h, w))

# Create base axes
ax1 = fig.add_axes([0.05, 0.05, 0.9, 0.9], aspect=1)
ax1.set_xticklabels([])
ax1.set_yticklabels([])
ax1.xaxis.set_ticks([])
ax1.yaxis.set_ticks([])
ax1.spines["top"].set_visible(False)
ax1.spines["right"].set_visible(False)

# Set up rotated axes
rotation = 45
xmin, xmax = -18, 18
ymin, ymax = 0, xmax - xmin
transform = Affine2D().rotate_deg(rotation-90)
helper = floating_axes.GridHelperCurveLinear(transform, (xmin, xmax, ymin, ymax))

# Create and configure floating subplot
ax2 = floating_axes.FloatingSubplot(fig, 111, grid_helper=helper, zorder=100)
ax2.patch.set_facecolor('green')
ax2.patch.set_alpha(0.3)
fig.add_subplot(ax2)

# Remove all axes elements
for axis in ["left", "right", "top", "bottom"]:
    ax2.axis[axis].set_visible(False)
ax2.set_xticks([])
ax2.set_yticks([])

# Plot heatmap on auxiliary axes
ax2_aux = ax2.get_aux_axes(transform)
sns.heatmap(upper_tri, cmap='Blues', cbar=False, ax=ax2_aux)

plt.show()

# %%
h, w = 12, 12
fig = plt.figure(figsize=(h, w))

# Define axis range to center the heatmap
xmin, xmax = -10, 10
ymin, ymax = -10, 10

# Adjust transform for rotation
rotation = 45
transform = Affine2D().rotate_deg(rotation)

# Set up grid helper with appropriate limits
helper = floating_axes.GridHelperCurveLinear(transform, (xmin, xmax, ymin, ymax))

# Create a rotated subplot
ax_rotated = floating_axes.FloatingSubplot(fig, 111, grid_helper=helper, zorder=100)
fig.add_subplot(ax_rotated)

# Set a background color for visualization
ax_rotated.patch.set_facecolor('green')
ax_rotated.patch.set_alpha(0.3)

# Remove ticks and spines for a clean look
for axis in ["left", "bottom", "top", "right"]:
    ax_rotated.axis[axis].set_visible(False)

# Get the auxiliary axis and plot the heatmap
ax_rotated_aux = ax_rotated.get_aux_axes(transform)
sns.heatmap(upper_tri, cmap='Blues', cbar=False, ax=ax_rotated_aux)

# Ensure no clipping and proper alignment

#plt.subplots_adjust(left=-1, right=0.9, top=0.9, bottom=0.1)  # Adjust overall figure positioning
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Create figure
plt.figure(figsize=(12, 12))

# Create sample data
upper_tri = np.triu(np.random.rand(10, 10))

# Create the heatmap
ax = sns.heatmap(upper_tri, cmap='Blues', cbar=False)

# Rotate the plot 45 degrees
ax.set_transform(ax.get_transform() + plt.matplotlib.transforms.Affine2D().rotate_deg(45))

# Adjust plot bounds to prevent clipping
plt.gcf().set_size_inches(15, 15)
plt.subplots_adjust(left=0.2, right=0.8, top=0.8, bottom=0.2)

plt.show()

# %%
# Remove all ticks, tick labels, and axis spines
ax2.axis["left"].major_ticklabels.set_visible(False)
ax2.axis["bottom"].major_ticklabels.set_visible(False)
ax2.axis["bottom"].major_ticks.set_visible(False)  # Remove bottom ticks
ax2.axis["left"].major_ticks.set_visible(False)    # Remove left ticks


ax2.axis["left"].set_visible(False)
ax2.axis["right"].set_visible(False)
ax2.axis["top"].set_visible(False)
ax2.axis["bottom"].set_visible(False)

# Optionally remove ticks entirely from the axis
ax2.set_xticks([])
ax2.set_yticks([])

# Ensure the axis patch remains visible if required
ax2.patch.set_visible(True)

ax2_aux = ax2.get_aux_axes(transform)
sns.heatmap(upper_tri, cmap='Blues', cbar=False,ax=ax2_aux)
ax2_aux.figure

# %%
ax2_aux = ax2.get_aux_axes(transform)
sns.heatmap(upper_tri, cmap='Blues', cbar=False,ax=ax2_aux)
ax2_aux.figure

# %%
sns.heatmap(upper_tri, cmap='Blues', cbar=False,ax=ax2_aux)
ax2_aux.figure
