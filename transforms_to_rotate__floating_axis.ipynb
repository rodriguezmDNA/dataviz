# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.transforms import Affine2D
import mpl_toolkits.axisartist.floating_axes as floating

# %%
fig = plt.figure(figsize=(8,8))
ax1 = plt.subplot(1,1,1, aspect=1,
                  xlim=[0,10], ylim=[0,10])

center = np.array([5,5])
size = np.array([5,3])
orientation = -30
T = size/2*[(-1,-1), (+1,-1), (+1,+1), (-1,+1)]
rotation = Affine2D().rotate_deg(orientation)
P = center + rotation.transform(T)

DC_to_FC = ax1.transData.transform
FC_to_NFC = fig.transFigure.inverted().transform
DC_to_NFC = lambda x: FC_to_NFC(DC_to_FC(x))

xmin, ymin = DC_to_NFC((P[:,0].min(), P[:,1].min()))
xmax, ymax = DC_to_NFC((P[:,0].max(), P[:,1].max()))
transform = Affine2D().rotate_deg(orientation)
helper = floating.GridHelperCurveLinear(
transform, (0, size[0], 0, size[1]))
ax2 = floating.FloatingSubplot(
fig, 111, grid_helper=helper, zorder=0)
ax2.set_position((xmin, ymin, xmax-xmin, ymax-xmin))
fig.add_subplot(ax2)
# Out:
# <FloatingAxesHostAxes: >

# %%
from matplotlib.patches import Circle
from copy import deepcopy



ax1.set_facecolor('0.9')
circle = Circle([8,8], 0.1, color='r',zorder=-1)
ax1.add_artist(circle)



circle = Circle([5,5], 0.1, color='r')
ax1.add_artist(circle)

ax1.hlines(5, 0, 10, color='r')
ax1.vlines(5, 0, 10, color='r')


circle = Circle([(ax2.get_xlim()[1] - ax2.get_xlim()[0])/2,
                 (ax2.get_ylim()[1] - ax2.get_ylim()[0])/2],
                 2, color='k',clip_on=False)

circle = Circle([(ax2.get_xlim()[1] - ax2.get_xlim()[0])/2,
                 (ax2.get_ylim()[1] - ax2.get_ylim()[0])/2],
                 2,
                 color='blue',
                 clip_on=True)

ax2.add_artist(circle)

# ax2.hlines(5, 0, 10, color='r')
# ax2.vlines(2, 0, 10, color='r')


ax1.figure

# %%
fig = plt.figure(figsize=(8,8))
ax1 = plt.subplot(1,1,1, aspect=1,
                  xlim=[0,10], ylim=[0,10])

center = np.array([5,5])
size = np.array([5,3])
orientation = -30
T = size/2*[(-1,-1), (+1,-1), (+1,+1), (-1,+1)]
rotation = Affine2D().rotate_deg(orientation)
P = center + rotation.transform(T)

DC_to_FC = ax1.transData.transform
FC_to_NFC = fig.transFigure.inverted().transform
DC_to_NFC = lambda x: FC_to_NFC(DC_to_FC(x))

xmin, ymin = DC_to_NFC((P[:,0].min(), P[:,1].min()))
xmax, ymax = DC_to_NFC((P[:,0].max(), P[:,1].max()))
transform = Affine2D().rotate_deg(orientation)
helper = floating.GridHelperCurveLinear(
transform, (0, size[0], 0, size[1]))
ax2 = floating.FloatingSubplot(
fig, 111, grid_helper=helper, zorder=0)
ax2.set_position((xmin, ymin, xmax-xmin, ymax-xmin))
fig.add_subplot(ax2)



center = np.array([5,5])
size = np.array([5,3])
orientation = 30
T = size/2*[(-1,-1), (+1,-1), (+1,+1), (-1,+1)]
rotation = Affine2D().rotate_deg(orientation)
P = center + rotation.transform(T)

DC_to_FC = ax1.transData.transform
FC_to_NFC = fig.transFigure.inverted().transform
DC_to_NFC = lambda x: FC_to_NFC(DC_to_FC(x))

xmin, ymin = DC_to_NFC((P[:,0].min(), P[:,1].min()))
xmax, ymax = DC_to_NFC((P[:,0].max(), P[:,1].max()))

transform = Affine2D().rotate_deg(orientation)
helper = floating.GridHelperCurveLinear(
transform, (0, size[0], 0, size[1]))

ax3 = floating.FloatingSubplot(fig, 111, grid_helper=helper, zorder=0)
ax3.set_position((xmin, ymin, xmax-xmin, ymax-xmin))
fig.add_subplot(ax3)


ax2.hist(np.random.randint(0, 10, 10))
# Out:
# (array([2., 1., 0., 0., 1., 2., 0., 1., 2., 1.]),
#  array([1. , 1.7, 2.4, 3.1, 3.8, 4.5, 5.2, 5.9, 6.6, 7.3, 8. ]),
#  <BarContainer object of 10 artists>)

# %%
# Out:
# (array([1., 1., 0., 2., 2., 1., 1., 1., 0., 1.]),
#  array([0. , 0.9, 1.8, 2.7, 3.6, 4.5, 5.4, 6.3, 7.2, 8.1, 9. ]),
#  <BarContainer object of 10 artists>)
